# %%
import pandas as pd

# 1. Автоматическое создание образца данных и сохранение в файл 'wild_boars.csv'
data = {
    'tusk_length': [12.5, 15.2, 9.8, 18.4, 14.1, 11.0, 16.7],
    'weight_kg': [95, 120, 80, 150, 110, 90, 135],
    'gender': ['male', 'female', 'female', 'male', 'male', 'female', 'male']
}
df_sample = pd.DataFrame(data)
df_sample.to_csv('wild_boars.csv', index=False)

# 2. Чтение созданного файла (Аналогично требованию задания)
df = pd.read_csv('wild_boars.csv')
column_name = 'tusk_length' 

# 3. Вывод результатов согласно требованию Задания 1
print("--- СТОЛБЕЦ С ДЛИНОЙ КЛЫКОВ ---")
print(df[column_name])

print("\n--- РЕЗУЛЬТАТЫ ПОИСКА ---")
print(f"Самые короткие клыки (минумум): {df[column_name].min()}")
print(f"Самые длинные клыки (максимум): {df[column_name].max()}")
# Out:
# --- СТОЛБЕЦ С ДЛИНОЙ КЛЫКОВ ---
# 0    12.5
# 1    15.2
# 2     9.8
# 3    18.4
# 4    14.1
# 5    11.0
# 6    16.7
# Name: tusk_length, dtype: float64
#
# --- РЕЗУЛЬТАТЫ ПОИСКА ---
# Самые короткие клыки (минумум): 9.8
# Самые длинные клыки (максимум): 18.4
